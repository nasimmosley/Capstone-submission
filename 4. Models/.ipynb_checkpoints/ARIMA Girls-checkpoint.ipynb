# %% [markdown]
# ### ALL POPULAR GIRLS NAMES

# %%
import pandas as pd
import numpy as np
import sktime
import statsmodels
import pmdarima as pmd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import statsmodels.api as sm
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.stattools import acf, pacf
from sklearn.metrics import mean_absolute_error, mean_squared_error
from datetime import datetime
from statsmodels.tsa.api import SimpleExpSmoothing, ExponentialSmoothing

# %%
females_pop=pd.read_csv('./Data/popular_females.csv', parse_dates =['year'], index_col="year")
female_names = pd.read_csv("./Data/female_names.csv",  parse_dates =['year'], index_col="year")
names_100_years = pd.read_csv("./Data/females_100count_10years_1920.csv", parse_dates =['year'], index_col="year")

# %% [markdown]
# ### Pull all popular girls names in a list/size it

# %%
females_name_list = females_pop["name"].unique().tolist()

# %%
len(females_name_list)
# Out:
# 1058

# %% [markdown]
# ### Find all popular girls names with at least 10 years of data in the dataset of 1920-2020

# %%
grouping= {}
group_list =[]
def name_ten_years(names,df):
    for name in names:
        
        Z=df[df["name"]==name][["count"]]
        
        grouping.update({name:Z.shape[0]})
    
        
    for k,v in sorted(grouping.items(), key=lambda x:x[1],reverse=True):
        if v <=10:
            group_list.append(k)
    
        df_dropped = df[~df["name"].isin(group_list)]
    
    return df_dropped

# %%
new_pop_females = name_ten_years(females_name_list, females_pop)

# %%
pop_females_list = new_pop_females["name"].unique().tolist()

# %%
len(pop_females_list)
# Out:
# 751

# %%
pop_females_list
# Out:
# ['Amelia',
#  'Alma',
#  'Velma',
#  'Katie',
#  'Jeannette',
#  'Audrey',
#  'Vivian',
#  'Laura',
#  'Anne',
#  'Maxine',
#  'Stella',
#  'Regina',
#  'Rita',
#  'Lila',
#  'Patricia',
#  'Lydia',
#  'Laverne',
#  'Marie',
#  'Susan',
#  'Josephine',
#  'Gladys',
#  'Shirley',
#  'Billie',
#  'Geraldine',
#  'Isabelle',
#  'Viola',
#  'Lillian',
#  'Donna',
#  'Vera',
#  'Nellie',
#  'Martha',
#  'Willie',
#  'Sally',
#  'Irene',
#  'Minnie',
#  'Ella',
#  'Leona',
#  'Wilma',
#  'Phyllis',
#  'Marian',
#  'Ellen',
#  'Faye',
#  'Bessie',
#  'Lillie',
#  'Kathleen',
#  'Bertha',
#  'Eva',
#  'Genevieve',
#  'Melba',
#  'Lorraine',
#  'Violet',
#  'Lucy',
#  'Marguerite',
#  'Louise',
#  'Norma',
#  'Catherine',
#  'Rose',
#  'Peggy',
#  'Bette',
#  'Sylvia',
#  'Opal',
#  'Veronica',
#  'Blanche',
#  'Mabel',
#  'Johnnie',
#  'Jessie',
#  'Gloria',
#  'Alice',
#  'Angelina',
#  'Claire',
#  'Ernestine',
#  'Annette',
#  'Jean',
#  'Hazel',
#  'Julia',
#  'Lena',
#  'Rosalie',
#  'Myrtle',
#  'June',
#  'Juanita',
#  'Kathryn',
#  'Isabel',
#  'Agnes',
#  'Mattie',
#  'Nancy',
#  'Jennie',
#  'Eileen',
#  'Ida',
#  'Charlotte',
#  'Florence',
#  'Eleanor',
#  'Mae',
#  'Marjorie',
#  'Victoria',
#  'Harriet',
#  'Gertrude',
#  'Marion',
#  'Clara',
#  'Sadie',
#  'Verna',
#  'Maggie',
#  'Jeanne',
#  'Olive',
#  'Carolyn',
#  'Flora',
#  'Georgia',
#  'Eloise',
#  'Ada',
#  'Cora',
#  'Adeline',
#  'Theresa',
#  'Jane',
#  'Ann',
#  'Mable',
#  'Betty',
#  'Dolores',
#  'Evelyn',
#  'Katherine',
#  'Barbara',
#  'Anna',
#  'Sara',
#  'Rebecca',
#  'Beulah',
#  'Virginia',
#  'Christine',
#  'Wanda',
#  'Nora',
#  'Sophie',
#  'Constance',
#  'Irma',
#  'Thelma',
#  'Marcella',
#  'Rosie',
#  'Caroline',
#  'Janet',
#  'Hilda',
#  'Lois',
#  'Carrie',
#  'Loretta',
#  'Susie',
#  'Esther',
#  'Inez',
#  'Muriel',
#  'Grace',
#  'Jeanette',
#  'Frances',
#  'Alberta',
#  'Lucille',
#  'Estelle',
#  'Fannie',
#  'Ethel',
#  'Beatrice',
#  'Erma',
#  'Lorene',
#  'Margie',
#  'Anita',
#  'Hattie',
#  'Daisy',
#  'Eunice',
#  'Bonnie',
#  'Mildred',
#  'Eula',
#  'Joyce',
#  'Rosa',
#  'Dora',
#  'Ruth',
#  'Margaret',
#  'Naomi',
#  'Rosemary',
#  'Mamie',
#  'Lola',
#  'Joan',
#  'Annie',
#  'Pauline',
#  'Helen',
#  'Roberta',
#  'Edith',
#  'Elsie',
#  'Ruby',
#  'Miriam',
#  'Arlene',
#  'Madeline',
#  'Lula',
#  'Geneva',
#  'Edna',
#  'Antoinette',
#  'Elaine',
#  'Della',
#  'Carol',
#  'Dorothy',
#  'Nina',
#  'Mary',
#  'Imogene',
#  'Marilyn',
#  'Jacqueline',
#  'Delores',
#  'Bettie',
#  'Carmen',
#  'Iris',
#  'Gwendolyn',
#  'Yvonne',
#  'Janice',
#  'Priscilla',
#  'Teresa',
#  'Bobbie',
#  'Joanne',
#  'Colleen',
#  'Joy',
#  'Patsy',
#  'Darlene',
#  'Jo',
#  'Charlene',
#  'Therese',
#  'Rosemarie',
#  'Ramona',
#  'Joann',
#  'Sue',
#  'Judith',
#  'Deloris',
#  'Connie',
#  'Diane',
#  'Patty',
#  'Carole',
#  'Pat',
#  'Marlene',
#  'Maureen',
#  'Suzanne',
#  'Marcia',
#  'Kay',
#  'Sharon',
#  'Linda',
#  'Dixie',
#  'Cynthia',
#  'Gail',
#  'Diana',
#  'Glenda',
#  'Jackie',
#  'Judy',
#  'Sheila',
#  'Karen',
#  'Paula',
#  'Maryann',
#  'Shelby',
#  'Deanna',
#  'Claudia',
#  'Sonja',
#  'Gayle',
#  'Dianne',
#  'Brenda',
#  'Lynn',
#  'Julie',
#  'Marianne',
#  'Lynda',
#  'Sherry',
#  'Pamela',
#  'Lynne',
#  'Marsha',
#  'Kathy',
#  'Angela',
#  'Valerie',
#  'Janie',
#  'Myra',
#  'Penny',
#  'Jacquelyn',
#  'Paulette',
#  'Vicki',
#  'Lana',
#  'Andrea',
#  'Bonita',
#  'Cecilia',
#  'Leslie',
#  'Michele',
#  'Terry',
#  'Cheryl',
#  'Bernadette',
#  'Sheryl',
#  'Jill',
#  'Sandy',
#  'Toni',
#  'Jennifer',
#  'Carla',
#  'Jan',
#  'Dianna',
#  'Janis',
#  'Trudy',
#  'Beth',
#  'Dawn',
#  'Becky',
#  'Candace',
#  'Denise',
#  'Cathy',
#  'Renee',
#  'Francine',
#  'Yolanda',
#  'Vickie',
#  'Doreen',
#  'Olivia',
#  'Lee',
#  'Wendy',
#  'Betsy',
#  'Robin',
#  'Cindy',
#  'Rhonda',
#  'Melanie',
#  'Debra',
#  'Terri',
#  'Vicky',
#  'Melinda',
#  'Kristine',
#  'Debbie',
#  'Monica',
#  'Amy',
#  'Laurie',
#  'Dana',
#  'Shelley',
#  'Belinda',
#  'Mona',
#  'Holly',
#  'Shelia',
#  'Patrice',
#  'Melody',
#  'Ginger',
#  'Lynette',
#  'Patti',
#  'Roxanne',
#  'Alicia',
#  'Tina',
#  'Kimberly',
#  'Nadine',
#  'Kim',
#  'Jody',
#  'Jeannie',
#  'Lori',
#  'Karla',
#  'Cathleen',
#  'Jamie',
#  'Marla',
#  'Debora',
#  'Sherri',
#  'Vanessa',
#  'Teri',
#  'Robyn',
#  'April',
#  'Sherrie',
#  'Jana',
#  'Jenny',
#  'Heidi',
#  'Sheri',
#  'Joni',
#  'Gina',
#  'Cheri',
#  'Tracy',
#  'Sabrina',
#  'Crystal',
#  'Darla',
#  'Christy',
#  'Ronda',
#  'Pam',
#  'Kelly',
#  'Yvette',
#  'Shelly',
#  'Tanya',
#  'Cassandra',
#  'Tamara',
#  'Tracey',
#  'Faith',
#  'Tami',
#  'Tammy',
#  'Jodi',
#  'Erin',
#  'Natalie',
#  'Stacy',
#  'Shari',
#  'Tammie',
#  'Alison',
#  'Rochelle',
#  'Kristi',
#  'Allison',
#  'Stacey',
#  'Sonia',
#  'Shannon',
#  'Heather',
#  'Lora',
#  'Kimberley',
#  'Tonya',
#  'Felicia',
#  'Bridget',
#  'Kelli',
#  'Kerry',
#  'Gretchen',
#  'Janine',
#  'Sonya',
#  'Lorie',
#  'Kelley',
#  'Angie',
#  'Traci',
#  'Joanna',
#  'Tara',
#  'Shawn',
#  'Katrina',
#  'Leticia',
#  'Kari',
#  'Celeste',
#  'Kellie',
#  'Jessica',
#  'Leah',
#  'Dina',
#  'Kristin',
#  'Tracie',
#  'Dena',
#  'Kristen',
#  'Molly',
#  'Trina',
#  'Monique',
#  'Kristina',
#  'Hope',
#  'Desiree',
#  'Mia',
#  'Cara',
#  'Kirsten',
#  'Krista',
#  'Stacie',
#  'Kerri',
#  'Kristy',
#  'Jodie',
#  'Kara',
#  'Christie',
#  'Ana',
#  'Adrienne',
#  'Misty',
#  'Amber',
#  'Erika',
#  'Erica',
#  'Kristie',
#  'Raquel',
#  'Tricia',
#  'Shawna',
#  'Megan',
#  'Aimee',
#  'Trisha',
#  'Rachelle',
#  'Tabitha',
#  'Kendra',
#  'Shana',
#  'Ashley',
#  'Candice',
#  'Nichole',
#  'Latonya',
#  'Christa',
#  'Angel',
#  'Rachael',
#  'Stefanie',
#  'Courtney',
#  'Mindy',
#  'Tasha',
#  'Keri',
#  'Natasha',
#  'Nikki',
#  'Brandi',
#  'Charity',
#  'Latasha',
#  'Bethany',
#  'Rebekah',
#  'Angelica',
#  'Tamika',
#  'Miranda',
#  'Latoya',
#  'Brooke',
#  'Jaime',
#  'Cristina',
#  'Mandy',
#  'Casey',
#  'Autumn',
#  'Alisha',
#  'Abigail',
#  'Ebony',
#  'Meghan',
#  'Lindsey',
#  'Marisa',
#  'Summer',
#  'Jaclyn',
#  'Kate',
#  'Janelle',
#  'Marissa',
#  'Jillian',
#  'Krystal',
#  'Jocelyn',
#  'Hillary',
#  'Whitney',
#  'Alexis',
#  'Adriana',
#  'Alyssa',
#  'Alissa',
#  'Alexandra',
#  'Jenna',
#  'Tia',
#  'Morgan',
#  'Lacey',
#  'Mayra',
#  'Abby',
#  'Meagan',
#  'Sophia',
#  'Carly',
#  'Cassie',
#  'Kira',
#  'Chelsea',
#  'Brianna',
#  'Caitlin',
#  'Kayla',
#  'Haley',
#  'Ashlee',
#  'Kelsey',
#  'Ashleigh',
#  'Bianca',
#  'Brittney',
#  'Dominique',
#  'Kasey',
#  'Alexandria',
#  'Savannah',
#  'Taylor',
#  'Mallory',
#  'Alana',
#  'Jordan',
#  'Elise',
#  'Britney',
#  'Gabrielle',
#  'Kaitlyn',
#  'Kaitlin',
#  'Sierra',
#  'Katelyn',
#  'Yesenia',
#  'Briana',
#  'Jade',
#  'Hayley',
#  'Paige',
#  'Sasha',
#  'Anastasia',
#  'Breanna',
#  'Allyson',
#  'Karina',
#  'Chelsey',
#  'Gabriela',
#  'Tiara',
#  'Caitlyn',
#  'Bailey',
#  'Destiny',
#  'Alexa',
#  'Sydney',
#  'Ariel',
#  'Kylie',
#  'Aubrey',
#  'Jasmin',
#  'Ariana',
#  'Mackenzie',
#  'Cierra',
#  'Chloe',
#  'Ciara',
#  'Camille',
#  'Arielle',
#  'Alejandra',
#  'Adrianna',
#  'Michaela',
#  'Kaylee',
#  'Mercedes',
#  'Madison',
#  'Tatiana',
#  'Kassandra',
#  'Raven',
#  'Guadalupe',
#  'Marina',
#  'Clarissa',
#  'Asia',
#  'Tessa',
#  'Mariah',
#  'Jazmine',
#  'Jazmin',
#  'Carolina',
#  'Callie',
#  'Gabriella',
#  'Hailey',
#  'Katlyn',
#  'Hanna',
#  'Shayla',
#  'Arianna',
#  'Tori',
#  'Katelynn',
#  'Daniela',
#  'Zoe',
#  'Maya',
#  'Cassidy',
#  'Kendall',
#  'Isabella',
#  'Valeria',
#  'Jordyn',
#  'Ashlyn',
#  'Mikayla',
#  'Brenna',
#  'Harley',
#  'Savanna',
#  'Imani',
#  'Selena',
#  'Elena',
#  'Logan',
#  'Alexia',
#  'Dakota',
#  'Madeleine',
#  'Kiana',
#  'Aaliyah',
#  'Makayla',
#  'Lily',
#  'Kylee',
#  'Sidney',
#  'Paola',
#  'Serena',
#  'Riley',
#  'Jada',
#  'Kennedy',
#  'Mckenna',
#  'Alondra',
#  'Natalia',
#  'Makenzie',
#  'Kyla',
#  'Julianna',
#  'Payton',
#  'Skylar',
#  'Peyton',
#  'Delaney',
#  'Kyra',
#  'Madelyn',
#  'Giselle',
#  'Avery',
#  'Juliana',
#  'Cameron',
#  'Aliyah',
#  'Nadia',
#  'Sofia',
#  'Esmeralda',
#  'Julissa',
#  'Reagan',
#  'Kailey',
#  'Macy',
#  'Mariana',
#  'Ava',
#  'Allie',
#  'Skyler',
#  'Liliana',
#  'Mya',
#  'Gianna',
#  'Alaina',
#  'Gracie',
#  'Josie',
#  'Jayla',
#  'Haylee',
#  'Kamryn',
#  'Rylee',
#  'Camryn',
#  'Makenna',
#  'Ellie',
#  'Heaven',
#  'Kayleigh',
#  'Ivy',
#  'Fatima',
#  'Addison',
#  'Amaya',
#  'Annabelle',
#  'Nevaeh',
#  'Layla',
#  'Zoey',
#  'Eliza',
#  'Daniella',
#  'Lilly',
#  'Serenity',
#  'Ashlynn',
#  'Jayden',
#  'Fiona',
#  'Bella',
#  'Camila',
#  'Brynn',
#  'Reese',
#  'Laila',
#  'Paris',
#  'Leila',
#  'Eliana',
#  'Alivia',
#  'Alayna',
#  'Eden',
#  'Piper',
#  'Talia',
#  'Leilani',
#  'Aniyah',
#  'Keira',
#  'Rylie',
#  'Lexi',
#  'Brooklynn',
#  'Aurora',
#  'Kaydence',
#  'Izabella',
#  'Tatum',
#  'Nyla',
#  'Sienna',
#  'Lucia',
#  'Ryleigh',
#  'Ximena',
#  'Ayla',
#  'Phoebe',
#  'Alessandra',
#  'Presley',
#  'London',
#  'Alina',
#  'Harmony',
#  'Scarlett',
#  'Emerson',
#  'Hayden',
#  'Lyla',
#  'Aubree',
#  'Valentina',
#  'Marley',
#  'Maddison',
#  'Madilyn',
#  'Delilah',
#  'Malia',
#  'Penelope',
#  'Brielle',
#  'Harper',
#  'Teagan',
#  'Khloe',
#  'Emery',
#  'Lilah',
#  'Hadley',
#  'Isla',
#  'Norah',
#  'Willow',
#  'Juliet',
#  'Paisley',
#  'Luna',
#  'Raegan',
#  'Adalyn',
#  'Lilliana',
#  'Lia',
#  'Londyn',
#  'Aria',
#  'Emilia',
#  'Noelle',
#  'Mila',
#  'Athena',
#  'Evangeline',
#  'Juliette',
#  'Arabella',
#  'Adelyn',
#  'Quinn',
#  'Kinsley']

# %% [markdown]
# ### RUN ARIMA PREDICTION MODEL ON FULL DATASET (1880-2020)

# %%
my_dict ={}
dict_list=[]

def name_modeler_scores(names, df):

    for name in names:
        
    
        Z = df[df["name"]==name][['count']]

        
        train, test = train_test_split(Z, shuffle=False, test_size=.30)
        
        df_preds = test.copy(deep=True)
        
        df_preds["baseline"]=train["count"][-1]
        
        mse_baseline = round(mean_absolute_error(df_preds["count"], df_preds["baseline"]),2)
        
        model=pmd.auto_arima(train["count"], error_action="ignore")
        
        preds = model.predict(len(test))
        
        df_preds["sarima"] = np.where(preds>0, preds, 0)
        
        mse_sarima = round(mean_absolute_error(df_preds["count"], df_preds["sarima"]),2)
    
        my_dict=({"name":name,"baseline mse": mse_baseline, "sarima mse": mse_sarima })
             
        dict_list.append(my_dict)
        
    return dict_list

# %%
name_modeler_scores("Jazmin", female_names)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-7c5e6d460fd0> in <module>
# ----> 1 name_modeler_scores("Jazmin", female_names)
#
# <ipython-input-38-c9e84220a41d> in name_modeler_scores(names, df)
#      10
#      11
# ---> 12         train, test = train_test_split(Z, shuffle=False, test_size=.30)
#      13
#      14         df_preds = test.copy(deep=True)
#
# ~/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_split.py in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2420
#    2421     n_samples = _num_samples(arrays[0])
# -> 2422     n_train, n_test = _validate_shuffle_split(
#    2423         n_samples, test_size, train_size, default_test_size=0.25
#    2424     )
#
# ~/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_split.py in _validate_shuffle_split(n_samples, test_size, train_size, default_test_size)
#    2096
#    2097     if n_train == 0:
# -> 2098         raise ValueError(
#    2099             "With n_samples={}, test_size={} and train_size={}, the "
#    2100             "resulting train set will be empty. Adjust any of the "
#
# ValueError: With n_samples=0, test_size=0.3 and train_size=None, the resulting train set will be empty. Adjust any of the aforementioned parameters.

# %%
Z= female_names[female_names["name"]=="Jazmin"][["count"]]

# %%
train, test = train_test_split(Z, shuffle=False, test_size=.30)
        
df_preds = test.copy(deep=True)
        
df_preds["baseline"]=train["count"][-1]
        
mse_baseline = round(mean_absolute_error(df_preds["count"], df_preds["baseline"]),2)
        
model=pmd.auto_arima(train["count"], error_action="ignore")
        
preds = model.predict(len(test))
        
df_preds["sarima"] = np.where(preds>0, preds, 0)

# %%
mse_sarima = round(mean_absolute_error(df_preds["count"], df_preds["sarima"]),2)

# %%
mse_baseline
# Out:
# 667.65

# %%
mse_sarima
# Out:
# 1033.82

# %%
name_modeler_scores("Cassidy", female_names)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-49b45bf69f8f> in <module>
# ----> 1 name_modeler_scores("Cassidy", female_names)
#
# <ipython-input-16-c9e84220a41d> in name_modeler_scores(names, df)
#      10
#      11
# ---> 12         train, test = train_test_split(Z, shuffle=False, test_size=.30)
#      13
#      14         df_preds = test.copy(deep=True)
#
# ~/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_split.py in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2420
#    2421     n_samples = _num_samples(arrays[0])
# -> 2422     n_train, n_test = _validate_shuffle_split(
#    2423         n_samples, test_size, train_size, default_test_size=0.25
#    2424     )
#
# ~/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_split.py in _validate_shuffle_split(n_samples, test_size, train_size, default_test_size)
#    2096
#    2097     if n_train == 0:
# -> 2098         raise ValueError(
#    2099             "With n_samples={}, test_size={} and train_size={}, the "
#    2100             "resulting train set will be empty. Adjust any of the "
#
# ValueError: With n_samples=0, test_size=0.3 and train_size=None, the resulting train set will be empty. Adjust any of the aforementioned parameters.

# %%
new_list = name_modeler_scores(pop_males_list, names_100_years)

# %%
new_names_data = pd.DataFrame(new_list)

# %%
new_names_data["percent diff in mses"] = (new_names_data["sarima mse"]-new_names_data["baseline mse"])/new_names_data["baseline mse"] * 100

# %%
bigger_baseline = new_names_data[new_names_data["baseline mse"]>new_names_data["sarima mse"]]

# %%
bigger_baseline.head()

# %%
bigger_baseline["name"].nunique()

# %%
smaller_baseline = new_names_data[new_names_data["baseline mse"]<new_names_data["sarima mse"]]

# %%
smaller_baseline.head()
# Out:
#          name  baseline mse  sarima mse  percent diff in mses
# 0       Glenn        542.90      553.02              1.864063
# 3    Theodore       1340.83     1402.77              4.619527
# 6      Victor        859.24     1424.23             65.754620
# 13  Frederick        500.31      539.30              7.793168
# 16       Leon        302.21      487.52             61.318289

# %%
smaller_baseline["name"].nunique()
# Out:
# 195

# %%
smaller_baseline[smaller_baseline["percent diff in mses"]>50]
# Out:
#          name  baseline mse  sarima mse  percent diff in mses
# 6      Victor        859.24     1424.23             65.754620
# 16       Leon        302.21      487.52             61.318289
# 24     Victor        859.24     1424.23             65.754620
# 34       Leon        302.21      487.52             61.318289
# 37     Harvey        165.93      250.04             50.690050
# ..        ...           ...         ...                   ...
# 467    Kayden        446.14     1808.84            305.442238
# 472     Rylan        621.00     1723.25            177.495974
# 475   Maximus        299.40      618.07            106.436206
# 477    Jaxson        278.67     2274.05            716.036890
# 480  Kingston        989.75     1704.53             72.218237
#
# [108 rows x 4 columns]

# %% [markdown]
# ### Look at plots of names with lower baseline MSE of at least 50 percent lower than SARIMA

# %%
names_100_years = pd.read_csv("./Data/males_100count_10years_1920.csv", parse_dates =['year'], index_col="year")

# %%
my_dict ={}
dict_list=[]

def name_modeler_scores(names, df):

    for name in names:
        
    
        Z = df[df["name"]==name][['count']]

        
        train, test = train_test_split(Z, shuffle=False, test_size=.10)
        
        df_preds = test.copy(deep=True)
        
        df_preds["baseline"]=train["count"][-1]
        
        mse_baseline = round(mean_absolute_error(df_preds["count"], df_preds["baseline"]),2)
        
        model=pmd.auto_arima(train["count"], error_action="ignore")
        
        preds = model.predict(len(test))
        
        df_preds["sarima"] = np.where(preds>0, preds, 0)
        
        mse_sarima = round(mean_absolute_error(df_preds["count"], df_preds["sarima"]),2)
    
        my_dict=({"name":name,"baseline mse": mse_baseline, "sarima mse": mse_sarima })
             
        dict_list.append(my_dict)
        
    return dict_list

# %%
small_baseline_list = name_modeler_scores("Cassidy", names_100_years)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-45-a80c195cf35d> in <module>
# ----> 1 small_baseline_list = name_modeler_scores("Cassidy", names_100_years)
#
# <ipython-input-38-c9e84220a41d> in name_modeler_scores(names, df)
#      10
#      11
# ---> 12         train, test = train_test_split(Z, shuffle=False, test_size=.30)
#      13
#      14         df_preds = test.copy(deep=True)
#
# ~/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_split.py in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2420
#    2421     n_samples = _num_samples(arrays[0])
# -> 2422     n_train, n_test = _validate_shuffle_split(
#    2423         n_samples, test_size, train_size, default_test_size=0.25
#    2424     )
#
# ~/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_split.py in _validate_shuffle_split(n_samples, test_size, train_size, default_test_size)
#    2096
#    2097     if n_train == 0:
# -> 2098         raise ValueError(
#    2099             "With n_samples={}, test_size={} and train_size={}, the "
#    2100             "resulting train set will be empty. Adjust any of the "
#
# ValueError: With n_samples=0, test_size=0.3 and train_size=None, the resulting train set will be empty. Adjust any of the aforementioned parameters.

# %%
small_data = pd.DataFrame(small_baseline_list)

# %%
small_data.head()

# %%
bigger_baseline = small_data[small_data["baseline mse"]>small_data["sarima mse"]]

# %%
bigger_baseline.head()

# %%
bigger_baseline["name"].nunique()

# %%
def plot_model(names, df):

    for name in names:
        
    
        Z = df[df["name"]==name][['count']]
        
        train, test = train_test_split(Z, shuffle=False, test_size=.20)
        
        df_preds = test.copy(deep=True)
        
        df_preds["baseline"]=train["count"][-1]

        
        model=pmd.auto_arima(train["count"], error_action="ignore")
        
        preds = model.predict(len(test))
        df_preds["sarima"] = np.where(preds>0, preds, 0)
        
        plt.figure(figsize=(8,8))
        plt.plot(train, label="train")
        plt.plot(test, label="test")
        plt.plot(df_preds["baseline"], label="baseline")
        plt.plot(df_preds["sarima"], label="sarima")
        plt.title(f'{name} Time Series prediction plot')
        plt.legend();

# %%
plot_model(smaller_baseline[smaller_baseline["percent diff in mses"]>50]["name"].unique().tolist()[:10], names_100_years)
